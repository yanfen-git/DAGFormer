# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from preprocess_smote import *
from sklearn.preprocessing import StandardScaler

# %%
# 药物列表
drugs = [
    'Gefitinib', 'Afatinib', 'AR-42', 'Cetuximab', 'Etoposide', 
    'NVP-TAE684', 'PLX4720', 'PLX4720_451Lu', 'Sorafenib', 'Vorinostat'
]

# %%
# 使用随机森林进行分类
def train_rf_model(features, labels):
    rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
    rf_model.fit(features, labels)
    return rf_model

# %%
# 评估模型
def evaluate_rf_model(rf_model, features, labels):
    preds = rf_model.predict(features)
    preds_proba = rf_model.predict_proba(features)
    
    # 计算准确率、AUC 和 AUPR
    accuracy = accuracy_score(labels, preds)
    auc = roc_auc_score(labels, preds_proba[:, 1])  # 使用第二列的概率值计算 AUC
    aupr = average_precision_score(labels, preds_proba[:, 1])  # 使用第二列的概率值计算 AUPR
    
    return accuracy, auc, aupr

# %%
# 主函数 - 执行实验
def run_rf_comparison(DRUG):
    # 训练：使用源数据集
    adj_s, features_s, labels_s, knn_s, n_features_s = load_data_drug('source', DRUG)
    
    # 测试：使用目标数据集
    adj_t, features_t, labels_t, knn_t, n_features_t = load_data_drug('target', DRUG)
    
    # 训练随机森林
    rf_model = train_rf_model(features_s, labels_s)
    
    # 测试：使用目标数据集
    accuracy, auc, aupr = evaluate_rf_model(rf_model, features_t, labels_t)
    
    # 输出结果
    print(f"Random Forest Performance for {DRUG}:")
    print(f"Accuracy: {accuracy:.4f}, AUC: {auc:.4f}, AUPR: {aupr:.4f}")
    return accuracy, auc, aupr

# %%
# 循环进行对比实验
for drug in drugs:
    acc, auc, aupr = run_rf_comparison(drug)
    print(f"Results for {drug} - Accuracy: {acc:.4f}, AUC: {auc:.4f}, AUPR: {aupr:.4f}")
# Out:
# 当前的采样率为: 100%
# [0.86127865 0.13872135]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 535
# Random Forest Performance for Gefitinib:
# Accuracy: 0.5152, AUC: 0.6129, AUPR: 0.6393
# Results for Gefitinib - Accuracy: 0.5152, AUC: 0.6129, AUPR: 0.6393
# 当前的采样率为: 100%
# [0.81971154 0.18028846]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 511
# Random Forest Performance for Afatinib:
# Accuracy: 0.6083, AUC: 0.6997, AUPR: 0.7054
# Results for Afatinib - Accuracy: 0.6083, AUC: 0.6997, AUPR: 0.7054
# 当前的采样率为: 100%
# [0.91021324 0.08978676]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# Random Forest Performance for AR-42:
# Accuracy: 0.5000, AUC: 0.7507, AUPR: 0.7755
# Results for AR-42 - Accuracy: 0.5000, AUC: 0.7507, AUPR: 0.7755
# 当前的采样率为: 100%
# [0.8583043 0.1416957]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 554
# Random Forest Performance for Cetuximab:
# Accuracy: 0.5417, AUC: 0.6643, AUPR: 0.6675
# Results for Cetuximab - Accuracy: 0.5417, AUC: 0.6643, AUPR: 0.6675
# 当前的采样率为: 100%
# [0.93865741 0.06134259]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# Random Forest Performance for Etoposide:
# Accuracy: 0.4508, AUC: 0.4525, AUPR: 0.5191
# Results for Etoposide - Accuracy: 0.4508, AUC: 0.4525, AUPR: 0.5191
# 当前的采样率为: 100%
# [0.90632911 0.09367089]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 268
# Random Forest Performance for NVP-TAE684:
# Accuracy: 0.5500, AUC: 0.6165, AUPR: 0.6134
# Results for NVP-TAE684 - Accuracy: 0.5500, AUC: 0.6165, AUPR: 0.6134
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# Random Forest Performance for PLX4720:
# Accuracy: 0.4352, AUC: 0.8613, AUPR: 0.8882
# Results for PLX4720 - Accuracy: 0.4352, AUC: 0.8613, AUPR: 0.8882
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# Random Forest Performance for PLX4720_451Lu:
# Accuracy: 0.5290, AUC: 0.4811, AUPR: 0.4810
# Results for PLX4720_451Lu - Accuracy: 0.5290, AUC: 0.4811, AUPR: 0.4810
# 当前的采样率为: 100%
# [0.92111959 0.07888041]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 271
# Random Forest Performance for Sorafenib:
# Accuracy: 0.5083, AUC: 0.5893, AUPR: 0.5778
# Results for Sorafenib - Accuracy: 0.5083, AUC: 0.5893, AUPR: 0.5778
# 当前的采样率为: 100%
# [0.92805755 0.07194245]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 580
# Random Forest Performance for Vorinostat:
# Accuracy: 0.5000, AUC: 0.7677, AUPR: 0.7571
# Results for Vorinostat - Accuracy: 0.5000, AUC: 0.7677, AUPR: 0.7571

# %%
import pandas as pd
from preprocess_smote import *  # 直接从 preprocess_smote 导入所有内容
from sklearn.linear_model import LogisticRegression  # 逻辑回归
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier  # 随机森林，AdaBoost
from sklearn.svm import SVC  # SVM支持向量机
from sklearn.tree import DecisionTreeClassifier  # 决策树
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score

# %%
# 药物列表
drugs = [
    'Gefitinib', 'Afatinib', 'AR-42', 'Cetuximab', 'Etoposide', 
    'NVP-TAE684', 'PLX4720', 'PLX4720_451Lu', 'Sorafenib', 'Vorinostat'
]

# %%
# 定义训练和评估模型的通用函数
def train_model(model, features, labels):
    model.fit(features, labels)
    return model

def evaluate_model(model, features, labels):
    preds = model.predict(features)
    preds_proba = model.predict_proba(features)
    
    # 计算准确率、AUC 和 AUPR
    accuracy = accuracy_score(labels, preds)
    auc = roc_auc_score(labels, preds_proba[:, 1])  # 使用第二列的概率值计算 AUC
    aupr = average_precision_score(labels, preds_proba[:, 1])  # 使用第二列的概率值计算 AUPR
    
    return accuracy, auc, aupr

# %%
# 主函数 - 执行实验
def run_comparison(DRUG, model):
    # 训练：使用源数据集
    adj_s, features_s, labels_s, knn_s, n_features_s = load_data_drug('source', DRUG)
    
    # 测试：使用目标数据集
    adj_t, features_t, labels_t, knn_t, n_features_t = load_data_drug('target', DRUG)
    
    # 训练模型
    model = train_model(model, features_s, labels_s)
    
    # 测试：使用目标数据集
    accuracy, auc, aupr = evaluate_model(model, features_t, labels_t)
    
    # 返回结果
    return DRUG, model.__class__.__name__, accuracy, auc, aupr

# %%
# 循环进行对比实验
models = [
    RandomForestClassifier(n_estimators=100, random_state=42),
    LogisticRegression(max_iter=1000, random_state=42),
    SVC(probability=True, random_state=42),  # SVM支持向量机，设置 probability=True 以获得预测概率
    DecisionTreeClassifier(random_state=42),
    AdaBoostClassifier(n_estimators=100, random_state=42)
]

# %%
# 存储所有实验结果的列表
results = []

# %%
# 循环进行对比实验
for drug in drugs:
    for model in models:
        drug_name, model_name, acc, auc, aupr = run_comparison(drug, model)
        results.append([drug_name, model_name, acc, auc, aupr])
# Out:
# 当前的采样率为: 100%
# [0.86127865 0.13872135]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 535
# 当前的采样率为: 100%
# [0.86127865 0.13872135]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 535
# 当前的采样率为: 100%
# [0.86127865 0.13872135]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 535
# 当前的采样率为: 100%
# [0.86127865 0.13872135]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 535
# 当前的采样率为: 100%
# [0.86127865 0.13872135]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 535
# 当前的采样率为: 100%
# [0.81971154 0.18028846]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 511
# 当前的采样率为: 100%
# [0.81971154 0.18028846]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 511
# 当前的采样率为: 100%
# [0.81971154 0.18028846]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 511
# 当前的采样率为: 100%
# [0.81971154 0.18028846]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 511
# 当前的采样率为: 100%
# [0.81971154 0.18028846]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 511
# 当前的采样率为: 100%
# [0.91021324 0.08978676]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# 当前的采样率为: 100%
# [0.91021324 0.08978676]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# 当前的采样率为: 100%
# [0.91021324 0.08978676]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# 当前的采样率为: 100%
# [0.91021324 0.08978676]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# 当前的采样率为: 100%
# [0.91021324 0.08978676]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# 当前的采样率为: 100%
# [0.8583043 0.1416957]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 554
# 当前的采样率为: 100%
# [0.8583043 0.1416957]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 554
# 当前的采样率为: 100%
# [0.8583043 0.1416957]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 554
# 当前的采样率为: 100%
# [0.8583043 0.1416957]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 554
# 当前的采样率为: 100%
# [0.8583043 0.1416957]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 554
# 当前的采样率为: 100%
# [0.93865741 0.06134259]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# 当前的采样率为: 100%
# [0.93865741 0.06134259]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# 当前的采样率为: 100%
# [0.93865741 0.06134259]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# 当前的采样率为: 100%
# [0.93865741 0.06134259]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# 当前的采样率为: 100%
# [0.93865741 0.06134259]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# 当前的采样率为: 100%
# [0.90632911 0.09367089]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 268
# 当前的采样率为: 100%
# [0.90632911 0.09367089]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 268
# 当前的采样率为: 100%
# [0.90632911 0.09367089]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 268
# 当前的采样率为: 100%
# [0.90632911 0.09367089]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 268
# 当前的采样率为: 100%
# [0.90632911 0.09367089]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 268
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# 当前的采样率为: 100%
# [0.92111959 0.07888041]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 271
# 当前的采样率为: 100%
# [0.92111959 0.07888041]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 271
# 当前的采样率为: 100%
# [0.92111959 0.07888041]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 271
# 当前的采样率为: 100%
# [0.92111959 0.07888041]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 271
# 当前的采样率为: 100%
# [0.92111959 0.07888041]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 271
# 当前的采样率为: 100%
# [0.92805755 0.07194245]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 580
# 当前的采样率为: 100%
# [0.92805755 0.07194245]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 580
# 当前的采样率为: 100%
# [0.92805755 0.07194245]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 580
# 当前的采样率为: 100%
# [0.92805755 0.07194245]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 580
# 当前的采样率为: 100%
# [0.92805755 0.07194245]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 580

# %%
# 将结果转换为 DataFrame
df_results = pd.DataFrame(results, columns=['Drug', 'Model', 'Accuracy', 'AUC', 'AUPR'])

# %%
# 输出结果到屏幕
print(df_results)

# 保存结果到 CSV 文件
df_results.to_csv('machineLearning_comparison_results.csv', index=False)
# Out:
#              Drug                   Model  Accuracy       AUC      AUPR
# 0       Gefitinib  RandomForestClassifier  0.545455  0.692837  0.677104
# 1       Gefitinib      LogisticRegression  0.636364  0.772268  0.728021
# 2       Gefitinib                     SVC  0.530303  0.466483  0.525563
# 3       Gefitinib  DecisionTreeClassifier  0.666667  0.666667  0.608108
# 4       Gefitinib      AdaBoostClassifier  0.484848  0.370064  0.435032
# 5        Afatinib  RandomForestClassifier  0.641667  0.770417  0.773821
# 6        Afatinib      LogisticRegression  0.558333  0.584722  0.576832
# 7        Afatinib                     SVC  0.533333  0.511806  0.581152
# 8        Afatinib  DecisionTreeClassifier  0.525000  0.525000  0.512963
# 9        Afatinib      AdaBoostClassifier  0.466667  0.492222  0.547226
# 10          AR-42  RandomForestClassifier  0.500000  0.761708  0.717803
# 11          AR-42      LogisticRegression  0.484848  0.651974  0.638351
# 12          AR-42                     SVC  0.484848  0.599633  0.601982
# 13          AR-42  DecisionTreeClassifier  0.484848  0.484848  0.492823
# 14          AR-42      AdaBoostClassifier  0.469697  0.263545  0.372966
# 15      Cetuximab  RandomForestClassifier  0.500000  0.496667  0.530807
# 16      Cetuximab      LogisticRegression  0.475000  0.429722  0.465221
# 17      Cetuximab                     SVC  0.466667  0.460278  0.500568
# 18      Cetuximab  DecisionTreeClassifier  0.516667  0.516667  0.508611
# 19      Cetuximab      AdaBoostClassifier  0.525000  0.572222  0.603326
# 20      Etoposide  RandomForestClassifier  0.424264  0.440572  0.504775
# 21      Etoposide      LogisticRegression  0.452979  0.545822  0.579522
# 22      Etoposide                     SVC  0.447236  0.590337  0.558791
# 23      Etoposide  DecisionTreeClassifier  0.524049  0.496430  0.546696
# 24      Etoposide      AdaBoostClassifier  0.548457  0.500624  0.562181
# 25     NVP-TAE684  RandomForestClassifier  0.475000  0.494167  0.502824
# 26     NVP-TAE684      LogisticRegression  0.558333  0.680000  0.677123
# 27     NVP-TAE684                     SVC  0.500000  0.457500  0.501989
# 28     NVP-TAE684  DecisionTreeClassifier  0.375000  0.375000  0.456633
# 29     NVP-TAE684      AdaBoostClassifier  0.475000  0.489167  0.496181
# 30        PLX4720  RandomForestClassifier  0.435185  0.723001  0.777916
# 31        PLX4720      LogisticRegression  0.555556  0.769285  0.814338
# 32        PLX4720                     SVC  0.425926  0.900771  0.935123
# 33        PLX4720  DecisionTreeClassifier  0.638889  0.632188  0.651605
# 34        PLX4720      AdaBoostClassifier  0.472222  0.430224  0.569691
# 35  PLX4720_451Lu  RandomForestClassifier  0.522581  0.435102  0.432893
# 36  PLX4720_451Lu      LogisticRegression  0.496774  0.418418  0.431507
# 37  PLX4720_451Lu                     SVC  0.445161  0.336670  0.374387
# 38  PLX4720_451Lu  DecisionTreeClassifier  0.490323  0.485485  0.470456
# 39  PLX4720_451Lu      AdaBoostClassifier  0.522581  0.496663  0.499224
# 40      Sorafenib  RandomForestClassifier  0.500000  0.588750  0.580662
# 41      Sorafenib      LogisticRegression  0.550000  0.735000  0.764071
# 42      Sorafenib                     SVC  0.525000  0.593611  0.600455
# 43      Sorafenib  DecisionTreeClassifier  0.433333  0.433333  0.469333
# 44      Sorafenib      AdaBoostClassifier  0.475000  0.489444  0.521758
# 45     Vorinostat  RandomForestClassifier  0.500000  0.696970  0.655708
# 46     Vorinostat      LogisticRegression  0.500000  0.591368  0.572755
# 47     Vorinostat                     SVC  0.500000  0.615243  0.632149
# 48     Vorinostat  DecisionTreeClassifier  0.636364  0.636364  0.623967
# 49     Vorinostat      AdaBoostClassifier  0.575758  0.675849  0.676112

# %%
# 四舍五入保留三位有效数字
df_results['Accuracy'] = df_results['Accuracy'].round(3)
df_results['AUC'] = df_results['AUC'].round(3)
df_results['AUPR'] = df_results['AUPR'].round(3)

# 输出修改后的结果
print(df_results)

# 如果需要，可以保存到 CSV 文件
df_results.to_csv('comparison_results_rounded.csv', index=False)
# Out:
#              Drug                   Model  Accuracy    AUC   AUPR
# 0       Gefitinib  RandomForestClassifier     0.545  0.693  0.677
# 1       Gefitinib      LogisticRegression     0.636  0.772  0.728
# 2       Gefitinib                     SVC     0.530  0.466  0.526
# 3       Gefitinib  DecisionTreeClassifier     0.667  0.667  0.608
# 4       Gefitinib      AdaBoostClassifier     0.485  0.370  0.435
# 5        Afatinib  RandomForestClassifier     0.642  0.770  0.774
# 6        Afatinib      LogisticRegression     0.558  0.585  0.577
# 7        Afatinib                     SVC     0.533  0.512  0.581
# 8        Afatinib  DecisionTreeClassifier     0.525  0.525  0.513
# 9        Afatinib      AdaBoostClassifier     0.467  0.492  0.547
# 10          AR-42  RandomForestClassifier     0.500  0.762  0.718
# 11          AR-42      LogisticRegression     0.485  0.652  0.638
# 12          AR-42                     SVC     0.485  0.600  0.602
# 13          AR-42  DecisionTreeClassifier     0.485  0.485  0.493
# 14          AR-42      AdaBoostClassifier     0.470  0.264  0.373
# 15      Cetuximab  RandomForestClassifier     0.500  0.497  0.531
# 16      Cetuximab      LogisticRegression     0.475  0.430  0.465
# 17      Cetuximab                     SVC     0.467  0.460  0.501
# 18      Cetuximab  DecisionTreeClassifier     0.517  0.517  0.509
# 19      Cetuximab      AdaBoostClassifier     0.525  0.572  0.603
# 20      Etoposide  RandomForestClassifier     0.424  0.441  0.505
# 21      Etoposide      LogisticRegression     0.453  0.546  0.580
# 22      Etoposide                     SVC     0.447  0.590  0.559
# 23      Etoposide  DecisionTreeClassifier     0.524  0.496  0.547
# 24      Etoposide      AdaBoostClassifier     0.548  0.501  0.562
# 25     NVP-TAE684  RandomForestClassifier     0.475  0.494  0.503
# 26     NVP-TAE684      LogisticRegression     0.558  0.680  0.677
# 27     NVP-TAE684                     SVC     0.500  0.458  0.502
# 28     NVP-TAE684  DecisionTreeClassifier     0.375  0.375  0.457
# 29     NVP-TAE684      AdaBoostClassifier     0.475  0.489  0.496
# 30        PLX4720  RandomForestClassifier     0.435  0.723  0.778
# 31        PLX4720      LogisticRegression     0.556  0.769  0.814
# 32        PLX4720                     SVC     0.426  0.901  0.935
# 33        PLX4720  DecisionTreeClassifier     0.639  0.632  0.652
# 34        PLX4720      AdaBoostClassifier     0.472  0.430  0.570
# 35  PLX4720_451Lu  RandomForestClassifier     0.523  0.435  0.433
# 36  PLX4720_451Lu      LogisticRegression     0.497  0.418  0.432
# 37  PLX4720_451Lu                     SVC     0.445  0.337  0.374
# 38  PLX4720_451Lu  DecisionTreeClassifier     0.490  0.485  0.470
# 39  PLX4720_451Lu      AdaBoostClassifier     0.523  0.497  0.499
# 40      Sorafenib  RandomForestClassifier     0.500  0.589  0.581
# 41      Sorafenib      LogisticRegression     0.550  0.735  0.764
# 42      Sorafenib                     SVC     0.525  0.594  0.600
# 43      Sorafenib  DecisionTreeClassifier     0.433  0.433  0.469
# 44      Sorafenib      AdaBoostClassifier     0.475  0.489  0.522
# 45     Vorinostat  RandomForestClassifier     0.500  0.697  0.656
# 46     Vorinostat      LogisticRegression     0.500  0.591  0.573
# 47     Vorinostat                     SVC     0.500  0.615  0.632
# 48     Vorinostat  DecisionTreeClassifier     0.636  0.636  0.624
# 49     Vorinostat      AdaBoostClassifier     0.576  0.676  0.676

# %%
from preprocess_smote import *  # 直接从 preprocess_smote 导入所有内容
from sklearn.naive_bayes import GaussianNB  # 导入朴素贝叶斯（高斯朴素贝叶斯）
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score

# 药物列表
drugs = [
    'Gefitinib', 'Afatinib', 'AR-42', 'Cetuximab', 'Etoposide', 
    'NVP-TAE684', 'PLX4720', 'PLX4720_451Lu', 'Sorafenib', 'Vorinostat'
]

# 使用朴素贝叶斯进行分类
def train_nb_model(features, labels):
    nb_model = GaussianNB()  # 使用高斯朴素贝叶斯（适用于连续数据）
    nb_model.fit(features, labels)
    return nb_model

# 评估模型
def evaluate_nb_model(nb_model, features, labels):
    preds = nb_model.predict(features)
    preds_proba = nb_model.predict_proba(features)
    
    # 计算准确率、AUC 和 AUPR
    accuracy = accuracy_score(labels, preds)
    auc = roc_auc_score(labels, preds_proba[:, 1])  # 使用第二列的概率值计算 AUC
    aupr = average_precision_score(labels, preds_proba[:, 1])  # 使用第二列的概率值计算 AUPR
    
    return accuracy, auc, aupr

# 主函数 - 执行实验
def run_nb_comparison(DRUG):
    # 训练：使用源数据集
    adj_s, features_s, labels_s, knn_s, n_features_s = load_data_drug('source', DRUG)
    
    # 测试：使用目标数据集
    adj_t, features_t, labels_t, knn_t, n_features_t = load_data_drug('target', DRUG)
    
    # 训练朴素贝叶斯
    nb_model = train_nb_model(features_s, labels_s)
    
    # 测试：使用目标数据集
    accuracy, auc, aupr = evaluate_nb_model(nb_model, features_t, labels_t)
    
    # 输出结果
    print(f"Naive Bayes Performance for {DRUG}:")
    print(f"Accuracy: {accuracy:.4f}, AUC: {auc:.4f}, AUPR: {aupr:.4f}")
    return accuracy, auc, aupr

# 循环进行对比实验
for drug in drugs:
    acc, auc, aupr = run_nb_comparison(drug)
    print(f"Results for {drug} - Accuracy: {acc:.4f}, AUC: {auc:.4f}, AUPR: {aupr:.4f}")
# Out:
# 当前的采样率为: 100%
# [0.86127865 0.13872135]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 535
# Naive Bayes Performance for Gefitinib:
# Accuracy: 0.5152, AUC: 0.5533, AUPR: 0.5272
# Results for Gefitinib - Accuracy: 0.5152, AUC: 0.5533, AUPR: 0.5272
# 当前的采样率为: 100%
# [0.81971154 0.18028846]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 511
# Naive Bayes Performance for Afatinib:
# Accuracy: 0.5167, AUC: 0.5350, AUPR: 0.5153
# Results for Afatinib - Accuracy: 0.5167, AUC: 0.5350, AUPR: 0.5153
# 当前的采样率为: 100%
# [0.91021324 0.08978676]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# Naive Bayes Performance for AR-42:
# Accuracy: 0.5303, AUC: 0.6795, AUPR: 0.6676
# Results for AR-42 - Accuracy: 0.5303, AUC: 0.6795, AUPR: 0.6676
# 当前的采样率为: 100%
# [0.8583043 0.1416957]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 554
# Naive Bayes Performance for Cetuximab:
# Accuracy: 0.5000, AUC: 0.4978, AUPR: 0.4952
# Results for Cetuximab - Accuracy: 0.5000, AUC: 0.4978, AUPR: 0.4952
# 当前的采样率为: 100%
# [0.93865741 0.06134259]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 608
# Naive Bayes Performance for Etoposide:
# Accuracy: 0.4436, AUC: 0.5495, AUPR: 0.5490
# Results for Etoposide - Accuracy: 0.4436, AUC: 0.5495, AUPR: 0.5490
# 当前的采样率为: 100%
# [0.90632911 0.09367089]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 268
# Naive Bayes Performance for NVP-TAE684:
# Accuracy: 0.4083, AUC: 0.4081, AUPR: 0.4520
# Results for NVP-TAE684 - Accuracy: 0.4083, AUC: 0.4081, AUPR: 0.4520
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# Naive Bayes Performance for PLX4720:
# Accuracy: 0.6111, AUC: 0.7242, AUPR: 0.7889
# Results for PLX4720 - Accuracy: 0.6111, AUC: 0.7242, AUPR: 0.7889
# 当前的采样率为: 100%
# [0.89448441 0.10551559]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 559
# Naive Bayes Performance for PLX4720_451Lu:
# Accuracy: 0.3742, AUC: 0.3353, AUPR: 0.4026
# Results for PLX4720_451Lu - Accuracy: 0.3742, AUC: 0.3353, AUPR: 0.4026
# 当前的采样率为: 100%
# [0.92111959 0.07888041]
# 类别为1的样本占总样本的比例: 0.4288
# 类别为1的样本数: 271
# Naive Bayes Performance for Sorafenib:
# Accuracy: 0.6083, AUC: 0.6639, AUPR: 0.6289
# Results for Sorafenib - Accuracy: 0.6083, AUC: 0.6639, AUPR: 0.6289
# 当前的采样率为: 100%
# [0.92805755 0.07194245]
# 类别为1的样本占总样本的比例: 0.4287
# 类别为1的样本数: 580
# Naive Bayes Performance for Vorinostat:
# Accuracy: 0.5152, AUC: 0.6731, AUPR: 0.6126
# Results for Vorinostat - Accuracy: 0.5152, AUC: 0.6731, AUPR: 0.6126
